# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.image as mpimg # for plot image

# %%
# %store -r master_data

# %%
# find sequential color map that works
cmap = sns.cubehelix_palette(dark=.3, light=.8, as_cmap=True)
nyc_img = mpimg.imread('/Users/jlmac01/Documents/PSTAT134/New_York_City_.png', 0)
plt.figure(figsize=[12, 11])
ax = sns.scatterplot(x='longitude', y='latitude', data=master_data, hue='price', palette=cmap)
plt.imshow(nyc_img, extent=[-74.26, -73.7, 40.49, 40.92], alpha=0.5)
plt.show()

# %%
nyc_img = mpimg.imread('/Users/jlmac01/Documents/PSTAT134/New_York_City_.png', 0)
plt.figure(figsize=[12, 11])
ax = sns.scatterplot(x='longitude', y='latitude', data=master_data, hue='room_type')
plt.imshow(nyc_img, extent=[-74.26, -73.7, 40.49, 40.92], alpha=0.5)
plt.show()

# %%
cmap = sns.cubehelix_palette(dark=.3, light=.8, as_cmap=True)
nyc_img = mpimg.imread('/Users/jlmac01/Documents/PSTAT134/New_York_City_.png', 0)
plt.figure(figsize=[12, 11])
ax = sns.scatterplot(x='longitude', y='latitude', data=master_data, hue='reviews_per_month', palette=cmap)
plt.imshow(nyc_img, extent=[-74.26, -73.7, 40.49, 40.92], alpha=0.5)
plt.show()

# %%
quantitative_data = master_data[['price','minimum_nights','number_of_reviews','calculated_host_listings_count',
                                 'availability_365']]
sns.heatmap(quantitative_data.corr(), annot=True, fmt='.3f');
